# %% [markdown]
# ### Aquire (Web-Scraping)

# %%
from bs4 import BeautifulSoup
import requests
import re
import pandas as pd

# %% [markdown]
# ## 1. Codeup Blog Articles
#
# Visit Codeup's Blog and record the urls for at least 5 distinct blog posts. For each post, you should scrape at least the post's title and content.
#
# Encapsulate your work in a function named get_blog_articles that will return a list of dictionaries, with each dictionary representing one article. The shape of each dictionary should look like this:

# %% [markdown]
# {
#     'title': 'the title of the article',
#     'content': 'the full text content of the article'
# }

# %%
url = 'https://codeup.com/blog/'

# %%
requests.get(url)
response = requests.get(url)

# %%
response
# Out:
# <Response [403]>

# %%
headers = {'User-Agent': 'Codeup Data Science'}
response = requests.get(url, headers=headers)

# %%
response
# Out:
# <Response [200]>

# %%
print(response.text)
# Out:
# <!DOCTYPE html>
# <html lang="en-US">
# <head>
# 	<meta charset="UTF-8" />
# <meta http-equiv="X-UA-Compatible" content="IE=edge">
# 	<link rel="pingback" href="https://codeup.com/xmlrpc.php" />
#
# 	<script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
#
# ...

# %%
print(response.content)
# Out:
# b'<!DOCTYPE html>\n<html lang="en-US">\n<head>\n\t<meta charset="UTF-8" />\n<meta http-equiv="X-UA-Compatible" content="IE=edge">\n\t<link rel="pingback" href="https://codeup.com/xmlrpc.php" />\n\n\t<script type="text/javascript">\n\t\tdocument.documentElement.className = \'js\';\n\t</script>\n\t\n\t<link rel="preconnect" href="https://fonts.gstatic.com" crossorigin /><script id="diviarea-loader">window.DiviPopupData=window.DiviAreaConfig={"zIndex":1000000,"animateSpeed":400,"triggerClassPrefix":"show-popup-","idAttrib":"data-popup","modalIndicatorClass":"is-modal","blockingIndicatorClass":"is-blocking","defaultShowCloseButton":true,"withCloseClass":"with-close","noCloseClass":"no-close","triggerCloseClass":"close","singletonClass":"single","darkModeClass":"dark","noShadowClass":"no-shadow","altCloseClass":"close-alt","popupSelector":".et_pb_section.popup","initializeOnEvent":"et_pb_after_init_modules","popupWrapperClass":"area-outer-wrap","fullHeightClass":"full-height","openPopupCl
# ...

# %%
#telling it you will feed it html
soup = BeautifulSoup(response.content, 'html.parser')
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en-US">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <link href="https://codeup.com/xmlrpc.php" rel="pingback"/>
# <script type="text/javascript">
# 		document.documentElement.className = 'js';
# 	</script>
# ...

# %%
len(soup.find_all('div'))
# Out:
# 166

# %%
len(soup.select('div'))
# Out:
# 166

# %%
soup.find_all('a', class_="entry-title")
# Out:
# []

# %%
soup.p
# Out:
# <p class="post-meta"><span class="published">Jan 5, 2023</span></p>

# %%
soup.find_all('a')
# Out:
# [<a href="https://codeup.com/">Home</a>,
#  <a href="https://codeup.com/program/cloud-adminsitration/">Cloud Administration</a>,
#  <a href="https://codeup.com/program/full-stack-web-development/">Full Stack Web Development</a>,
#  <a href="https://codeup.com/program/data-science/">Data Science</a>,
#  <a href="/events/">Workshops</a>,
#  <a href="/san-antonio-events/">San Antonio</a>,
#  <a href="/dallas-events/">Dallas</a>,
#  <a href="https://codeup.com/financial-aid/">Financial Aid</a>,
#  <a href="https://codeup.com/veterans/">Military</a>,
#  <a href="https://codeup.com/hire-tech-talent/">Hire Tech Talent</a>,
#  <a href="https://alumni.codeup.com/">Alumni</a>,
#  <a href="https://codeup.com/resources/">Resources</a>,
#  <a href="/my-story/">Student Reviews</a>,
#  <a aria-current="page" href="https://codeup.com/blog/">Blog</a>,
#  <a href="https://codeup.com/frequently-asked-questions/">Common Questions</a>,
#  <a href="https://codeup.com/podcast/">Hire Tech Podcast</a>,
# ...

# %%
list_of_a_elements = soup.find_all('a')
list_of_a_elements
# Out:
# [<a href="https://codeup.com/">Home</a>,
#  <a href="https://codeup.com/program/cloud-adminsitration/">Cloud Administration</a>,
#  <a href="https://codeup.com/program/full-stack-web-development/">Full Stack Web Development</a>,
#  <a href="https://codeup.com/program/data-science/">Data Science</a>,
#  <a href="/events/">Workshops</a>,
#  <a href="/san-antonio-events/">San Antonio</a>,
#  <a href="/dallas-events/">Dallas</a>,
#  <a href="https://codeup.com/financial-aid/">Financial Aid</a>,
#  <a href="https://codeup.com/veterans/">Military</a>,
#  <a href="https://codeup.com/hire-tech-talent/">Hire Tech Talent</a>,
#  <a href="https://alumni.codeup.com/">Alumni</a>,
#  <a href="https://codeup.com/resources/">Resources</a>,
#  <a href="/my-story/">Student Reviews</a>,
#  <a aria-current="page" href="https://codeup.com/blog/">Blog</a>,
#  <a href="https://codeup.com/frequently-asked-questions/">Common Questions</a>,
#  <a href="https://codeup.com/podcast/">Hire Tech Podcast</a>,
# ...

# %%
list_of_a_elements[1].text
# Out:
# 'Cloud Administration'

# %%
list_of_a_elements[1]
# Out:
# <a href="https://codeup.com/program/cloud-adminsitration/">Cloud Administration</a>

# %%
for element in list_of_a_elements:
    print(element)
# Out:
# <a href="https://codeup.com/">Home</a>
# <a href="https://codeup.com/program/cloud-adminsitration/">Cloud Administration</a>
# <a href="https://codeup.com/program/full-stack-web-development/">Full Stack Web Development</a>
# <a href="https://codeup.com/program/data-science/">Data Science</a>
# <a href="/events/">Workshops</a>
# <a href="/san-antonio-events/">San Antonio</a>
# <a href="/dallas-events/">Dallas</a>
# <a href="https://codeup.com/financial-aid/">Financial Aid</a>
# <a href="https://codeup.com/veterans/">Military</a>
# <a href="https://codeup.com/hire-tech-talent/">Hire Tech Talent</a>
# <a href="https://alumni.codeup.com/">Alumni</a>
# <a href="https://codeup.com/resources/">Resources</a>
# <a href="/my-story/">Student Reviews</a>
# <a aria-current="page" href="https://codeup.com/blog/">Blog</a>
# <a href="https://codeup.com/frequently-asked-questions/">Common Questions</a>
# <a href="https://codeup.com/podcast/">Hire Tech Podcast</a>
# ...

# %%
# function to extract html document from given url
def getHTMLdocument(url):
    # request for HTML document of given url
    headers = {'User-Agent': 'Codeup Data Science'}
    response = requests.get(url, headers=headers)
    # response will be provided in JSON format
    return response.text


# assign required credentials
# assign URL
url_to_scrape = "https://codeup.com/blog/"

# create document
html_document = getHTMLdocument(url_to_scrape)

# create soap object
soup = BeautifulSoup(html_document, 'html.parser')


# find all the anchor tags with "href"
# attribute starting with "https://"
for link in soup.find_all('a', attrs={'href': re.compile("^https://")}):
    # display the actual urls
    print(link.get('href'))
# Out:
# https://codeup.com/
# https://codeup.com/program/cloud-adminsitration/
# https://codeup.com/program/full-stack-web-development/
# https://codeup.com/program/data-science/
# https://codeup.com/financial-aid/
# https://codeup.com/veterans/
# https://codeup.com/hire-tech-talent/
# https://alumni.codeup.com/
# https://codeup.com/resources/
# https://codeup.com/blog/
# https://codeup.com/frequently-asked-questions/
# https://codeup.com/podcast/
# https://codeup.com/apply-now/
# https://codeup.com/
# https://codeup.com/programs/
# https://codeup.com/program/cloud-administration/
# https://codeup.com/program/full-stack-web-development/
# https://codeup.com/program/data-science/
# https://codeup.com/san-antonio-events/
# https://codeup.com/dallas-events/
# https://codeup.com/veterans/
# https://codeup.com/san-antonio/
# https://codeup.com/dallas/
# https://codeup.com/hire-tech-talent/
# https://codeup.com/hire-tech-talent/
# https://alumni.codeup.com/
# https://codeup.com/resources/
# ...

# %%
print(soup.h1)
# Out:
# <h1>Codeup News &amp; Articles</h1>

# %%
soup.h1('entry-content')
# Out:
# []

# %%
h1tags = soup.find_all('h1')
for soups in h1tags:
    print(soups.string)
# Out:
# Codeup News & Articles

# %%
tags = soup.find_all(['a', 'h1', 'title'])
for soups in tags:
    print(soups.string)
# Out:
# Blog - Codeup
# Home
# Cloud Administration
# Full Stack Web Development
# Data Science
# Workshops
# San Antonio
# Dallas
# Financial Aid
# Military
# Hire Tech Talent
# Alumni
# Resources
# Student Reviews
# Blog
# Common Questions
# Hire Tech Podcast
# Apply Now
# None
# About
# Behind The Billboards
# Careers
# None
# Programs
# Cloud Administration
# Web Development
# Data Science
# Financing
# Events
# San Antonio
# Dallas
# Military
# Campuses
# San Antonio
# Dallas
# Hire
# Employers
# Alumni Portal
# Resources
# Student Reviews
# Blog
# Common Questions
# Hire Tech Podcast
# Start Now
# Codeup News & Articles
# None
# Become a Data Scientist in 6 Months!
# read more
# None
# Hiring Tech Talent Around the Holidays
# read more
# None
# Cloud Administration Program New Funding Options
# read more
# None
# Why Dallas is a Great Location for IT Professionals
# read more
# None
# Codeup is ranked #1 Best in DFW 2022
# read more
# None
# Codeup’s Scholarship Offerings
# read more
# ...

# %% [markdown]
# ### class= 'more-link' is one way to get access to each article linke

# %%
soup.find_all('a', class_='more-link')
# Out:
# [<a class="more-link" href="https://codeup.com/data-science/become-a-data-scientist/">read more</a>,
#  <a class="more-link" href="https://codeup.com/employers/hiring-tech-talent/">read more</a>,
#  <a class="more-link" href="https://codeup.com/cloud-administration/cap-funding-options/">read more</a>,
#  <a class="more-link" href="https://codeup.com/dallas-info/it-professionals-dallas/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-voted-1-technical-school-in-dfw/">read more</a>,
#  <a class="more-link" href="https://codeup.com/tips-for-prospective-students/financing/codeups-scholarships/">read more</a>]

# %%
soup.find_all('a', class_='more-link')
# Out:
# [<a class="more-link" href="https://codeup.com/data-science/become-a-data-scientist/">read more</a>,
#  <a class="more-link" href="https://codeup.com/employers/hiring-tech-talent/">read more</a>,
#  <a class="more-link" href="https://codeup.com/cloud-administration/cap-funding-options/">read more</a>,
#  <a class="more-link" href="https://codeup.com/dallas-info/it-professionals-dallas/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-voted-1-technical-school-in-dfw/">read more</a>,
#  <a class="more-link" href="https://codeup.com/tips-for-prospective-students/financing/codeups-scholarships/">read more</a>]

# %%
#. means a class
soup.select('a.more-link')
# Out:
# [<a class="more-link" href="https://codeup.com/data-science/become-a-data-scientist/">read more</a>,
#  <a class="more-link" href="https://codeup.com/employers/hiring-tech-talent/">read more</a>,
#  <a class="more-link" href="https://codeup.com/cloud-administration/cap-funding-options/">read more</a>,
#  <a class="more-link" href="https://codeup.com/dallas-info/it-professionals-dallas/">read more</a>,
#  <a class="more-link" href="https://codeup.com/codeup-news/codeup-voted-1-technical-school-in-dfw/">read more</a>,
#  <a class="more-link" href="https://codeup.com/tips-for-prospective-students/financing/codeups-scholarships/">read more</a>]

# %%
soup.select('a.more-link')[0]['href'] #[href] gives you back just the link
# Out:
# 'https://codeup.com/data-science/become-a-data-scientist/'

# %%
blog_posts = [link['href'] for link in soup.select('a.more-link')]
blog_posts
# Out:
# ['https://codeup.com/data-science/become-a-data-scientist/',
#  'https://codeup.com/employers/hiring-tech-talent/',
#  'https://codeup.com/cloud-administration/cap-funding-options/',
#  'https://codeup.com/dallas-info/it-professionals-dallas/',
#  'https://codeup.com/codeup-news/codeup-voted-1-technical-school-in-dfw/',
#  'https://codeup.com/tips-for-prospective-students/financing/codeups-scholarships/']

# %%
def get_blog_urls(url, header = {'User-Agent': 'Codeup Data Science'}):
    soup = BeautifulSoup(requests.get(url, headers=header).content, 'html.parser')
    return [link['href'] for link in soup.select('a.more-link')]

# %%
get_blog_urls(url, header = {'User-Agent': 'Codeup Data Science'})
# Out:
# ['https://codeup.com/data-science/become-a-data-scientist/',
#  'https://codeup.com/employers/hiring-tech-talent/',
#  'https://codeup.com/cloud-administration/cap-funding-options/',
#  'https://codeup.com/dallas-info/it-professionals-dallas/',
#  'https://codeup.com/codeup-news/codeup-voted-1-technical-school-in-dfw/',
#  'https://codeup.com/tips-for-prospective-students/financing/codeups-scholarships/']

# %%
article = BeautifulSoup(requests.get('https://codeup.com/data-science/become-a-data-scientist/', headers=headers).content)

# %%
article.select_one('h1.entry-title').text
# Out:
# 'Become a Data Scientist in 6 Months!'

# %%
### White space could mean a division object for web scrapers!

# %%
article.select_one('div.entry-content').text.strip()
# Out:
# 'Are you feeling unfulfilled in your work but want to avoid returning to the traditional educational route? Codeup can help! Starting over as a professional is daunting and not always ideal. Codeup can help you go from a career you are bored with, to a job that excites you in just 6 months!\nHere’s how…\nData Science Program\nDuring our 20-week program, you will have the opportunity to take your career to new heights with data science being one of the most needed jobs in tech.\nYou’ll gather data, then clean it, explore it for trends, and apply machine learning models to make predictions.\nUpon completing this program, you will know how to turn insights into actionable recommendations. You’ll be a huge asset to any company, having all the technical skills to become a data scientist with projects upon projects of experience under your belt.\nCodeup\nA common reason individuals opt not to change their careers is fear it is too late. Codeup has crafted a program that will guide you thro
# ...

# %%
def get_blog_articles(url):
    urls = get_blog_urls(url, header = {'User-Agent': 'Codeup Data Science'})
    headers = {'User-Agent': 'Codeup Data Science'}
    output = []
    for blog in urls:
        article = BeautifulSoup(requests.get(blog, headers=headers).content)
        blog_output = {'title': article.select_one('h1.entry-title').text, 'content': article.select_one('div.entry-content').text.strip()}
        output.append(blog_output)
        
    return pd.DataFrame(output)

# %%
get_blog_articles(url)
# Out:
#                                                title  \
# 0               Become a Data Scientist in 6 Months!
# 1             Hiring Tech Talent Around the Holidays
# 2   Cloud Administration Program New Funding Options
# 3  Why Dallas is a Great Location for IT Professi...
# 4               Codeup is ranked #1 Best in DFW 2022
# 5                     Codeup’s Scholarship Offerings
#
#                                              content
# 0  Are you feeling unfulfilled in your work but w...
# 1  Are you a hiring manager having trouble fillin...
# 2  Finding resources to fund your educational goa...
# 3  When breaking into a new career, it is importa...
# 4  We are excited to announce that Codeup ranked ...
# 5  In honor of November being National Scholarshi...

# %% [markdown]
# ### 2. News Articles
#
# We will now be scraping text data from inshorts, a website that provides a brief overview of many different topics.
#
# Write a function that scrapes the news articles for the following topics:
#
# * Business
# * Sports
# * Technology
# * Entertainment
# * The end product of this should be a function named get_news_articles that returns a list of dictionaries, where each dictionary has this shape:

# %%
url2 = 'https://inshorts.com/en/read'

# %%
#200 means successful
requests.get(url2)
response = requests.get(url2)

# %%
response
# Out:
# <Response [200]>

# %%
#x path of link
# /html/body/div[4]/div/div[3]/div[1]/div/div[2]/a

# %%
soup = BeautifulSoup(response.content, 'html.parser')

# %% [markdown]
# ### Title stored under a span heading

# %%
#Get title
soup.find_all('span', itemprop='headline')[0].text
# Out:
# "Drunk man smoked in toilet, another peed on woman's blanket on Air India flight"

# %%
#Get content
soup.find_all('div', itemprop='articleBody')[0].text
# Out:
# "A drunk passenger smoked in the toilet on a Paris-Delhi Air India flight on December 6, the DGCA said. This is the same Paris-Delhi flight on which another drunk man urinated on a woman co-passenger's blanket when she went to the lavatory. Separately, Shankar Mishra was arrested for urinating on a woman on Air India's November 26 New York-Delhi flight."

# %%
#Get categories
#categories from assignment = ['business', 'sports', 'technology', 'entertainment']
categories = [li.text.lower() for li in soup.select('li')][1:] #One forward, skipping india
categories[0] = 'national'
categories
# Out:
# ['national',
#  'business',
#  'sports',
#  'world',
#  'politics',
#  'technology',
#  'startup',
#  'entertainment',
#  'miscellaneous',
#  'hatke',
#  'science',
#  'automobile']

# %%
results = soup.find_all('div', class_='card-stack')

# %%
print(results)
# Out:
# [<div class="card-stack">
# <div class="">
# <div class="news-card z-depth-1" itemscope="" itemtype="http://schema.org/NewsArticle">
# <span content="" itemid="https://inshorts.com/en/news/i-recently-rejected-a-big-film-i-never-run-after-money-diljit-dosanjh-1673198669556" itemprop="mainEntityOfPage" itemscope="" itemtype="https://schema.org/WebPage"></span>
# <span itemprop="author" itemscope="itemscope" itemtype="https://schema.org/Person">
# <span content="Anmol Sharma" itemprop="name"></span>
# </span>
# <span content="I recently rejected a big film, I never run after money: Diljit Dosanjh" itemprop="description"></span>
# <span itemprop="image" itemscope="" itemtype="https://schema.org/ImageObject">
# <meta content="https://static.inshorts.com/inshorts/images/v1/variants/jpg/m/2023/01_jan/8_sun/img_1673198024611_162.jpg?" itemprop="url"/>
# <meta content="864" itemprop="width"/>
# <meta content="483" itemprop="height"/>
# </span>
# ...

# %%
articles = results.find('div', class_ ='news-card z-depth-1')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[43], line 1
# ----> 1 articles = results.find('div', class_ ='news-card z-depth-1')
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/bs4/element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# AttributeError: ResultSet object has no attribute 'find'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?

# %%
def get_titles(soup):
    titles = []
    results = soup.find_all('div', class_='card-stack')
    articles = results.find('div', class_ ='news-card z-depth-1')
    for result in results:
    for article in articles:
        content = articles.find('div', itemprop='articleBody')
        a_ = articles.find('a')
        title = a_.find(itemprop ='headline').get_text()
        titles.append(title)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[37], line 5
#       3 articles = results.find_all('div', class_ ='news-card z-depth-1')
#       4 for article in articles:
# ----> 5     content = articles.find_all('div', itemprop='articleBody')
#       6     a_ = articles.find('a')
#       7     title = a_.find(itemprop ='headline').get_text()
#
# File /opt/homebrew/anaconda3/lib/python3.9/site-packages/bs4/element.py:2289, in ResultSet.__getattr__(self, key)
#    2287 def __getattr__(self, key):
#    2288     """Raise a helpful exception to explain a common code fix."""
# -> 2289     raise AttributeError(
#    2290         "ResultSet object has no attribute '%s'. You're probably treating a list of elements like a single element. Did you call find_all() when you meant to call find()?" % key
#    2291     )
#
# ...

# %%
titles
# Out:
# ['I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
#  'I recently rejected a big film, I never run after money: Diljit Dosanjh',
# ...
